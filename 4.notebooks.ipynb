# %% [markdown]
# # 📈 Extreme Imbalance Analysis
#
# **Observation:** The customer file exhibits an **Extreme Imbalance**, where the DELUX segment accounts for **99.61%** of the total customer base, while the VIP segment only represents **0.04%** (2 customers).

# %% [markdown]
# ## 1. VIP Segment (0.04% - Critically Important)
#
# **Evidence:**
# * **Size:** Represents a mere 0.04% of the total customer base.
# * **Frequency (F):** VIP customers show an average purchase frequency of 344 times, which is 63.7 times higher than the DELUX group (5.4 times).
# * **Monetary Value (M):** The average transaction value is $115,895.60, which is 79 times higher than the DELUX group ($1,465.39).

# %% [markdown]
# ## 2. STANDARD Segment (0.35% - Potential Pool)
#
# **Evidence:**
# * **Size:** Accounts for 0.35% of the total customers.
# * **Recency (R):** This segment exhibits a good Recency score, with an average of 24 days since the last purchase.
# * **Frequency (F):** The average purchase frequency is 109 times, which is 20 times higher than the DELUX group (5.4 times).

# %% [markdown]
# ## 3. DELUX Segment (99.61% - Risk & Cost)
#
# **Evidence:**
# * **Size:** Overwhelmingly dominates the customer base at 99.61%.
# * **Recency (R):** This group has a poor average Recency score of 201 days.
# * **Frequency (F):** Average purchase frequency is very low, at only 5.4 times.
# * **Monetary Value (M):** Average spending is low, at $1,465.39.
